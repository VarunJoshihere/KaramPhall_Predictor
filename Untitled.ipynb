# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Download,Load,Visualise and Normalize
x=pd.read_csv('./Linear_X_Train.csv')
y=pd.read_csv('./Linear_Y_Train.csv')
x.head()
y.head()
# Out:
#            y
# 0  -0.091101
# 1 -53.467721
# 2  75.457009
# 3 -12.025286
# 4  57.414187

# %%
plt.style.use('seaborn')
plt.scatter(x,y)

# %%
x.shape
# Out:
# (3750, 1)

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
#converting from DataFrame to np arrays
X=x.values
y=y.values
#Normalization
u=X.mean()
std=X.std()
X=(X-u)/std
plt.style.use('seaborn')
plt.scatter(X,y,color='orange')
plt.title("Time vs performance")
plt.xlabel("HARdwork")
plt.ylabel("Performance")
plt.show()

# %%
##IMplementing linear regression

# %%
def hypothesis(x,theta):
    #function generates y cap value
    #theta=[theta0,theta1]
    y_=theta[0]+theta[1]*x
    return y_

def gradient(X,Y,theta):
    m=X.shape[0]
    grad=np.zeros((2,))
    for i in range(m):
        x=X[i]
        y_=hypothesis(x,theta)
        y=Y[i]
        grad[0]+=(y_-y)
        grad[1]+=(y_-y)*x
        
    return grad/m

def error(X,Y,theta):
    m=X.shape[0]
    total_error=0.0
    for i in range(m):
        y_=hypothesis(X[i],theta)
        total_error+=(y_-Y[i])**2
        
    return total_error/m


def gradientDescent(X,Y,max_steps=100,learning_rate=0.1):
    theta=np.zeros((2,))
    error_list=[]
    for i in range (max_steps):
        
        grad=gradient(X,Y,theta)
        e=error(X,Y,theta)
        error_list.append(e)
        theta[0]=theta[0]-learning_rate*grad[0]
        theta[1]=theta[1]-learning_rate*grad[1]
        
    return theta,error_list

# %%
theta,error_list=gradientDescent(X,y)

# %%
theta
# Out:
# array([ 0.6838508 , 79.90361453])

# %%
error_list
# Out:
# [array([6576.35005246]),
#  array([5363.12510257]),
#  array([4380.41289317]),
#  array([3584.41600355]),
#  array([2939.65852295]),
#  array([2417.40496367]),
#  array([1994.37958066]),
#  array([1651.72902041]),
#  array([1374.18206661]),
#  array([1149.36903404]),
#  array([967.27047765]),
#  array([819.77064698]),
#  array([700.29578413]),
#  array([603.52114523]),
#  array([525.13368772]),
#  array([461.63984713]),
#  array([410.20983626]),
#  array([368.55152745]),
#  array([334.80829731]),
#  array([307.47628091]),
#  array([285.33734761]),
#  array([267.40481165]),
#  array([252.87945752]),
#  array([241.11392067]),
#  array([231.58383582]),
#  array([223.8644671]),
#  array([217.61177843]),
#  array([212.54710061]),
#  array([208.44471157]),
#  array([205.12177646]),
#  array([202.43019901]),
#  array([200.25002128]),
#  array([198.48407732]),
#  array([197.05366271]),
#  array([195.89502687]),
#  array([194.95653185]),
#  array([194.19635088]),
#  array([193.58060429]),
#  array([193.08184956]),
#  array([192.67785822]),
#  array([192.35062524]),
#  array([192.08556653]),
#  array([191.87086897]),
#  array([191.69696394]),
#  array([191.55610088]),
#  array([191.44200179]),
#  array([191.34958153]),
#  array([191.27472112]),
#  array([191.21408419]),
#  array([191.16496827]),
#  array([191.12518438]),
#  array([191.09295943]),
#  array([191.06685722]),
#  array([191.04571443]),
#  array([191.02858877]),
#  array([191.01471698]),
#  array([191.00348084]),
#  array([190.99437956]),
#  array([190.98700752]),
#  array([190.98103617]),
#  array([190.97619938]),
#  array([190.97228158]),
#  array([190.96910816]),
#  array([190.96653769]),
#  array([190.96445561]),
#  array([190.96276913]),
#  array([190.96140307]),
#  array([190.96029657]),
#  array([190.9594003]),
#  array([190.95867433]),
#  array([190.95808628]),
#  array([190.95760997]),
#  array([190.95722416]),
#  array([190.95691165]),
#  array([190.95665852]),
#  array([190.95645348]),
#  array([190.9562874]),
#  array([190.95615287]),
#  array([190.95604391]),
#  array([190.95595565]),
#  array([190.95588415]),
#  array([190.95582625]),
#  array([190.95577934]),
#  array([190.95574135]),
#  array([190.95571057]),
#  array([190.95568564]),
#  array([190.95566545]),
#  array([190.9556491]),
#  array([190.95563585]),
#  array([190.95562512]),
#  array([190.95561643]),
#  array([190.95560939]),
#  array([190.95560368]),
#  array([190.95559906]),
#  array([190.95559532]),
#  array([190.95559229]),
#  array([190.95558984]),
#  array([190.95558785]),
#  array([190.95558624]),
#  array([190.95558493])]

# %%
plt.plot(error_list)

# %%
##PRedictions and BEst Line

y_=hypothesis(X,theta)
print(y_)
# Out:
# [[-19.5733619 ]
#  [-43.69571729]
#  [ 86.4848761 ]
#  ...
#  [-20.85044708]
#  [138.70197319]
#  [-35.87897262]]

# %%
#plott training data + prediction
plt.scatter(X,y)
plt.plot(X,y_,color="orange",label="Prediction")
plt.legend()
plt.show()

# %%
#Load test data
X_test=pd.read_csv('./Linear_X_Test.csv')
y_test=hypothesis(X_test,theta)
y_test.shape
# Out:
# (1250, 1)

# %%
##submit as csv
df=pd.DataFrame(data=y_test,columns=["y"])

# %%
 df.to_csv('prediction.csv',index=False)

# %%
#computing score
def r2_score(Y,Y_):
    num=np.sum((Y-Y_)**2)
    denom=np.sum((Y-Y.mean())**2)
    score=(1-(num/denom))
    return score*100

# %%
r2_score(y,y_)
# Out:
# 97.09612226971643
